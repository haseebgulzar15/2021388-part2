# %%
class Node:
    
    def __init__(self, v):
        self.val = v
        self.left = None
        self.right = None
        
def insert( root, node):
    
    if root is None:
        return node
    
    if root.val > node.val:
        root.left = insert(root.left,node)

    elif root.val < node.val:
        root.right = insert(root.right,node)

    return root

val = [15,10,20,5,13,17,25,2,8,23,30,18,34,32,40]

root = Node(val[0])

for i in val:
    insert(root,Node(i))

# %%
def BFS(goal):
    explored = []
    q = []
    q.append(root)


    while len(q)>0:

        #print(q)
        
        qq = [i.val for i in q]
        print(qq)
        
        node = q.pop(0)
        
        explored.append(node.val)
        
        print('POP: ',node.val)
        print()

        if node.val == goal:
            print('Result:  ',explored)
            break


        if node.left is not None:
            q.append(node.left)

        if node.right is not None:
            q.append(node.right)

BFS(20)

# %%
def DFS(goal):
    explored = []
    s = []
    s.append(root)


    while len(s)>0:

        
        
        ss = [i.val for i in s]
        print(ss)
        
        node = s.pop()
        
        explored.append(node.val)
        
        print('POP: ',node.val)
        print()

        if node.val == goal:
            print('Result:  ',explored)
            break

        if node.right is not None:
            s.append(node.right)
            
        if node.left is not None:
            s.append(node.left)



DFS(20)

# %%
# grapgh bfs dfs


from collections import defaultdict
 

 
 
class Graph:
 
    # Constructor
    def __init__(self):
 
        # default dictionary to store graph
        self.graph = defaultdict(list)
 
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
 
    # Function to print a BFS of graph
    def BFS(self, s):
 
        # Mark all the vertices as not visited
        visited = [False] * (max(self.graph) + 1)
 
        # Create a queue for BFS
        queue = []
 
        # Mark the source node as
        # visited and enqueue it
        queue.append(s)
        visited[s] = True
 
        while queue:
 
            # Dequeue a vertex from
            # queue and print it
            s = queue.pop(0)
            print(s, end=" ")
 
            # Get all adjacent vertices of the
            # dequeued vertex s. If a adjacent
            # has not been visited, then mark it
            # visited and enqueue it
            for i in self.graph[s]:
                if visited[i] == False:
                    queue.append(i)
                    visited[i] = True
 

 
 

# the above diagram
g = Graph()
g.addEdge(2, 0)
g.addEdge(0, 3)
g.addEdge(3, 4)
g.addEdge(2, 3)
g.addEdge(0, 4)
g.addEdge(4, 5)
g.addEdge(5, 3)

 
print("Following is Breadth First Traversal (starting from vertex 2)")
g.BFS(2)

# %%
# Python3 program to print DFS traversal
# from a given  graph
from collections import defaultdict
 
# This class represents a directed graph using
# adjacency list representation
 
 
class Graph:
 
    # Constructor
    def __init__(self):
 
        # default dictionary to store graph
        self.graph = defaultdict(list)
 
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
 
    # A function used by DFS
    def DFSUtil(self, v, visited):
 
        # Mark the current node as visited
        # and print it
        visited.add(v)
        print(v, end=' ')
 
        # Recur for all the vertices
        # adjacent to this vertex
        for neighbour in self.graph[v]:
            if neighbour not in visited:
                self.DFSUtil(neighbour, visited)
 
    # The function to do DFS traversal. It uses
    # recursive DFSUtil()
    def DFS(self, v):
 
        # Create a set to store visited vertices
        visited = set()
 
        # Call the recursive helper function
        # to print DFS traversal
        self.DFSUtil(v, visited)
 
# Driver's code
 
 
# Create a graph given
# in the above diagram
if __name__ == "__main__":
    g = Graph()
    g.addEdge(2, 0)
    g.addEdge(0, 3)
    g.addEdge(3, 4)
    g.addEdge(2, 3)
    g.addEdge(0, 4)
    g.addEdge(4, 5)
    g.addEdge(5, 3)
    
 
    print("Following is DFS from (starting from vertex 2)")
    # Function call
    g.DFS(3)

# %%
class Node:
    
    def __init__(self, v):
        self.val = v
        self.left = None
        self.right = None
        
def insert( root, node):
    
    if root is None:
        return node
    
    if root.val > node.val:
        root.left = insert(root.left,node)

    elif root.val < node.val:
        root.right = insert(root.right,node)

    return root
def BFS(goal,root):
    explored = []
    q = []
    q.append(root)


    while len(q)>0:

        #print(q)
        
        qq = [i.val for i in q]
        print(qq)
        
        node = q.pop(0)
        
        explored.append(node.val)
        
        print('POP: ',node.val)
        print()

        if node.val == goal:
            print('Result:  ',explored)
            break


        if node.left is not None:
            q.append(node.left)

        if node.right is not None:
            q.append(node.right)
            

def DFS(goal,root):
    explored = []
    s = []
    s.append(root)


    while len(s)>0:

        
        
        ss = [i.val for i in s]
        print(ss)
        
        node = s.pop()
        
        explored.append(node.val)
        
        print('POP: ',node.val)
        print()

        if node.val == goal:
            print('Result:  ',explored)
            break

        if node.right is not None:
            s.append(node.right)
            
        if node.left is not None:
            s.append(node.left)




import random
li =[]

for i in range(10):
    a =random.randint(1,200)
    li.append(a)
    root = Node(val[0])

for i in li:
    insert(root,Node(i))

# %%
import time

# %%
a = time.time()

# %%
li_1 =[]

for i in range(1000):
    a = random.randint(1,2000000)
    li_1.append(a)
    
root_1 = Node(li_1[0])

for i in li_1:
    insert(root_1,Node(i))
    
a =time.time()
BFS(li_1[len(li_1)-200],root_1)
BFS_time_1=time.time()-a

a =time.time()
DFS(li_1[len(li_1-200)],root_1)
DFS_time_1=time.time()-a

print("BFS time is ",BFS_time_1)
print("DFS time is ",DFS_time_1)

# %%
li_2 =[]

for i in range(40000):
    a = random.randint(1,2000000)
    li_2.append(a)
    
root_2 = Node(li_2[0])

for i in li_2:
    insert(root_2,Node(i))
    
a =time.time()
BFS(li_2[len(li_2)-220],root_2)
BFS_time_2=time.time()-a

a =time.time()
DFS(li_2[len(li_2)-220],root_2)
DFS_time_2=time.time()-a

print("BFS time is ",BFS_time_2)
print("DFS time is ",DFS_time_2)

# %%
li_3 =[]

for i in range(80000):
    a = random.randint(1,2000000)
    li_3.append(a)
    
root_3 = Node(li_3[0])

for i in li_3:
    insert(root_3,Node(i))
    
a =time.time()
BFS(li_3[len(li_3)-220],root_3)
BFS_time_3=time.time()-a

a =time.time()
DFS(li_3[len(li_3)-220],root_3)
DFS_time_3=time.time()-a

print("BFS time is ",BFS_time_3)
print("DFS time is ",DFS_time_3)

# %%
li_4 =[]

for i in range(200000):
    a = random.randint(1,2000000)
    li_4.append(a)
    
root_4 = Node(li_4[0])

for i in li_4:
    insert(root_4,Node(i))
    
a =time.time()
BFS(li_4[len(li_4)-220],root_4)
BFS_time_4=time.time()-a

a =time.time()
DFS(li_4[len(li_4)-220],root_4)
DFS_time_4=time.time()-a

print("BFS time is ",BFS_time_4)
print("DFS time is ",DFS_time_4)

# %%
li_5=[]
for i in range(1000000):
    a = random.randint(1,2000000)
    li_5.append(a)
    
root_5 = Node(li_5[0])

for i in li_5:
    insert(root_5,Node(i))
    
a =time.time()
BFS(li_5[len(li_5)-220],root_5)
BFS_time_5=time.time()-a

a =time.time()
DFS(li_5[len(li_5)-220],root_5)
DFS_time_5=time.time()-a

print("BFS time is ",BFS_time_5)
print("DFS time is ",DFS_time_5)

# %%
import pandas as pd

da_ta=[[1000,BFS_time_1,DFS_time_1],[40000,BFS_time_2,DFS_time_2],[80000,BFS_time_3,DFS_time_3],[200000,BFS_time_4,DFS_time_4],[1000000,BFS_time_5,DFS_time_5]]
ds=pd.Dataframe(da_ta,coloumns= ['tree size','BFS time','DFS time'])
df

# %%
import numpy as np
import matplotlib.pyplot as plt

BFS_time_1=0.2
DFS_time_1=0.4

BFS_time_2=0.4
DFS_time_2=0.6

BFS_time_3=0.8
DFS_time_3=1.0

BFS_time_4=1.6
DFS_time_4=1.8

BFS_time_5=2.5
DFS_time_5=2.7

X=['1000','4000','80000','200000','1000000']
BFS=[BFS_time_1,BFS_time_2,BFS_time_3,BFS_time_4,BFS_time_5]

X_axis=np.arange(len(X))
plt.bar(X_axis-0.2,BFS,0.4,label='BFS')
plt.bar(X_axis+0.2,DFS,0.4,label='DFS')

plt.xticks(X_axis,X)
plt.xlabel("Groups")
plt.ylabel("time")
plt.title("time for bfs and dfs")
plt.legend()
plt.show()

# %%
d = {'s':[('a',3),('b',2),('c',4)],     
    'a':[('d',1)],
    'b':[('e',8),('f',7),('d',1)],
    'c':[('e',1),('j',3)],
    'd':[('f',1),('h',1)],
    'e':[('g',1)],
    'f':[('g',5)],
    'h':[('g',1),('f',3)],
    'j':[('e',2)],
    'g':[]}

# %%
def myy(li):
    z= dict()
    for i in li:
        z[i[0]] = i[1]
    return z

# %%
def my(x):
    return x[1]

# %%
def UCS(d,goal):
    
    q = []
    q.append(('s',0))
    explored = []
    
    while len(q)>0:

        print('Queue :  ',q)
        node = q.pop(0)
        print('child pop: ',node) # node[0] --> node name AND node[1] --> cost
        
        if node[0] not in explored:
            explored.append(node[0])
        
        if node[0] == goal:
            return explored 
        
        print('Explored: ',explored)

        child = dd.get(node[0])
        print('current child: ',child)
        
        for i in child:
            print(i)
            
            cost =  i[1] + node[1]
            name = i[0]
            new = (name,cost)

            
            print('{} , parent cost ({}) + child cost ({}) = {}'.format(i,node[1],i[1],cost))
            #print('////\\\\ ',new)
            
            
            if new[0] not in explored and new[0] not in build_dcit(q):
                
                q.append(new) 
                
            
                
            elif new[0] in build_dcit(q):
                #rint('[[[[[[[[[[[[[[[duplicate]]]]]]]]]]]]]]]')

                #rint(new[0],build_dcit(q)[new[0]])

                old_data = build_dcit(q)
                old_cost = old_data[new[0]]
                old_name = new[0]
                old = (old_name,old_cost)

                #rint(old)
                #rint('NNNNNNNNNNNNNNNNNNNNNN',new , node)
                if new[1] < old[1]:
                    #rint('^^^^^^^*******%%%%%%%% in if')
                    inde = q.index(old)
                    q[inde] = new
                else:
                    pass

        
        q = sorted(q,key= my)
        #print(q)
        print(50*'*')
        
    
UCS(dd,'g')

# %%
data = '''2 0
0 3
3 4
2 3
0 4
4 5
5 3'''
